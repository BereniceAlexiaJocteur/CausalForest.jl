# %%
using CausalForest
using Plots
using StatsBase
# Out:
# ┌ Info: Precompiling CausalForest [31bdf679-24a7-499a-9be9-b214c66174ea]
# └ @ Base loading.jl:1423

# %%
indices,X,T,Y = load_data("causal");
Xtest = rand(Float64, (1000, size(X, 2)));
Xtest[:, 1] =  LinRange(0, 1, 1000);
true_effect = Xtest[:, 1].>0.5;

# %% [markdown]
# # Subsampling not honest

# %%
cf1 = build_forest_1(false, false, false, Y, T, X, false, -1, 100, 0.7, 0.5, -1, 10, 20);
pred1 = apply_forest_1(cf1, Xtest);

# %%
pred1
# Out:
# 1000-element Vector{Float64}:
#  -0.28786269889277605
#  -0.264230028412196
#  -0.08151381275485373
#  -0.08973878991907294
#  -0.04555816462013143
#  -0.029805520705964126
#   0.19854690730913335
#  -0.44237270051465344
#  -0.21052512625079983
#   0.06095806774328515
#   0.05326988078628585
#  -0.02993128730665094
#   0.10473087694152124
#   ⋮
#   1.1178184157923428
#   0.6373752942302172
#   1.1038889239451892
#   0.9407671270306774
#   1.0490239553486862
#   0.5808718317526942
#   1.1096710392962477
#   1.1065364955536188
#   1.0666642106149968
#   1.392848770427996
#   1.1720072205407779
#   1.0479472117604438

# %%
plot(Xtest[:, 1], [true_effect, pred1], label=["True effect" "Estimation"], title = "No centering no bootstrap no honest", fmt = :png)

# %%
rmsd(float(true_effect), pred1)
# Out:
# 0.21918180014443606

# %%
importance(cf1)
# Out:
# 10-element Vector{Float64}:
#  0.1488763735937672
#  0.08115097030825777
#  0.011551615084014652
#  0.16069985377012633
#  0.028682657909829573
#  0.008518516739742172
#  0.1251922223924327
#  0.3825346775362169
#  0.019920141178762223
#  0.03287297148685045

# %% [markdown]
# # Subsampling honest

# %%
cf3 = build_forest_1(false, false, true, Y, T, X, false, -1, 100);
pred3 = apply_forest_1(cf3, Xtest);

# %%
rmsd(float(true_effect), pred3)
# Out:
# 0.11687687549539566

# %% [markdown]
# # Bootstrap not honest

# %%
cf5 = build_forest_1(false, true, false, Y, T, X, false, -1, 100);
pred5 = apply_forest_1(cf5, Xtest);

# %%
rmsd(float(true_effect), pred5)
# Out:
# 0.244217823374944

# %% [markdown]
# # Bootstrap honest

# %%
cf7 = build_forest_1(false, true, true, Y, T, X, false, -1, 100);
pred7 = apply_forest_1(cf7, Xtest);

# %%
rmsd(float(true_effect), pred7)
# Out:
# 0.14553663653599877

# %% [markdown]
# # 500 arbres

# %% [markdown]
# # Subsampling not honest

# %%
cf1 = build_forest_1(false, false, false, Y, T, X, false, -1, 500);
pred1 = apply_forest_1(cf1, Xtest);

# %%
rmsd(float(true_effect), pred1)
# Out:
# 0.22255104971238066

# %% [markdown]
# # Subsampling honest

# %%
cf3 = build_forest_1(false, false, true, Y, T, X, false, -1, 500);
pred3 = apply_forest_1(cf3, Xtest);

# %%
rmsd(float(true_effect), pred3)
# Out:
# 0.10422010575498047

# %% [markdown]
# # Bootstrap not honest

# %%
cf5 = build_forest_1(false, true, false, Y, T, X, false, -1, 500);
pred5 = apply_forest_1(cf5, Xtest);

# %%
rmsd(float(true_effect), pred5)
# Out:
# 0.22448476408497128

# %% [markdown]
# # Bootstrap honest

# %%
cf7 = build_forest_1(false, true, true, Y, T, X, false, -1, 500);
pred7 = apply_forest_1(cf7, Xtest);

# %%
rmsd(float(true_effect), pred7)
# Out:
# 0.1283746638066473

# %%
plot(Xtest[:, 1], [true_effect, pred7], label=["True effect" "Estimation"], title = "No centering bootstrap honest", fmt = :png)

# %%
importance(cf7)
# Out:
# 10-element Vector{Float64}:
#  0.12129028309028791
#  0.07689532074726445
#  0.05671183814611042
#  0.1316037091205837
#  0.06058117505168635
#  0.05103547512627368
#  0.17600944483052655
#  0.18922265542080977
#  0.06447286058255128
#  0.07217723788390583
